# %% [markdown]
# # Personality Prediction

# %%
import pandas as pd
df = pd.read_csv("data-final.csv", delimiter="\t")

# %%
df
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  ...  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0  ...
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0  ...
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0  ...
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0  ...
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0  ...
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0  ...
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0  ...
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0  ...
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0  ...
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0  ...
#
#                     dateload  screenw  screenh  introelapse  testelapse  \
# ...

# %%
columns = df.columns

# %%
for column in columns:
    print(column)
# Out:
# EXT1
# EXT2
# EXT3
# EXT4
# EXT5
# EXT6
# EXT7
# EXT8
# EXT9
# EXT10
# EST1
# EST2
# EST3
# EST4
# EST5
# EST6
# EST7
# EST8
# EST9
# EST10
# AGR1
# AGR2
# AGR3
# AGR4
# AGR5
# AGR6
# AGR7
# AGR8
# AGR9
# AGR10
# CSN1
# CSN2
# CSN3
# CSN4
# CSN5
# CSN6
# CSN7
# CSN8
# CSN9
# CSN10
# OPN1
# OPN2
# OPN3
# OPN4
# OPN5
# OPN6
# OPN7
# OPN8
# OPN9
# OPN10
# EXT1_E
# EXT2_E
# EXT3_E
# EXT4_E
# EXT5_E
# EXT6_E
# EXT7_E
# EXT8_E
# EXT9_E
# EXT10_E
# EST1_E
# EST2_E
# EST3_E
# EST4_E
# EST5_E
# EST6_E
# EST7_E
# EST8_E
# EST9_E
# EST10_E
# AGR1_E
# AGR2_E
# AGR3_E
# AGR4_E
# AGR5_E
# AGR6_E
# AGR7_E
# AGR8_E
# AGR9_E
# AGR10_E
# CSN1_E
# CSN2_E
# CSN3_E
# CSN4_E
# CSN5_E
# CSN6_E
# CSN7_E
# CSN8_E
# CSN9_E
# CSN10_E
# OPN1_E
# OPN2_E
# OPN3_E
# OPN4_E
# OPN5_E
# OPN6_E
# OPN7_E
# OPN8_E
# OPN9_E
# OPN10_E
# dateload
# screenw
# screenh
# introelapse
# testelapse
# endelapse
# IPC
# country
# lat_appx_lots_of_err
# long_appx_lots_of_err

# %%
import numpy as np

# %%
X = df[df.columns[0:50]]

# %%
pd.set_option("display.max_columns", None)

# %%
X
# Out:
#          EXT1  EXT2  EXT3  EXT4  EXT5  EXT6  EXT7  EXT8  EXT9  EXT10  EST1  \
# 0         4.0   1.0   5.0   2.0   5.0   1.0   5.0   2.0   4.0    1.0   1.0
# 1         3.0   5.0   3.0   4.0   3.0   3.0   2.0   5.0   1.0    5.0   2.0
# 2         2.0   3.0   4.0   4.0   3.0   2.0   1.0   3.0   2.0    5.0   4.0
# 3         2.0   2.0   2.0   3.0   4.0   2.0   2.0   4.0   1.0    4.0   3.0
# 4         3.0   3.0   3.0   3.0   5.0   3.0   3.0   5.0   3.0    4.0   1.0
# ...       ...   ...   ...   ...   ...   ...   ...   ...   ...    ...   ...
# 1015336   4.0   2.0   4.0   3.0   4.0   3.0   3.0   3.0   3.0    3.0   4.0
# 1015337   4.0   3.0   4.0   3.0   3.0   3.0   4.0   4.0   3.0    3.0   4.0
# 1015338   4.0   2.0   4.0   3.0   5.0   1.0   4.0   2.0   4.0    4.0   3.0
# 1015339   2.0   4.0   3.0   4.0   2.0   2.0   1.0   4.0   2.0    4.0   4.0
# 1015340   4.0   2.0   4.0   2.0   4.0   1.0   4.0   2.0   4.0    4.0   4.0
#
# ...

# %%
X = X.fillna(0)

# %%
from sklearn.cluster import MiniBatchKMeans

# Create and fit your MiniBatchKMeans model
kmeans = MiniBatchKMeans(n_clusters=10, random_state=0, batch_size=1024, max_iter=100)
kmeans.fit(X)  # Assuming X is your data

# Access the cluster centers using the 'cluster_centers' attribute
cluster_centers = kmeans.cluster_centers_

# Now you can use 'cluster_centers' for further analysis or visualization
print("Cluster Centers:", cluster_centers)
# Out:
# C:\Users\manas\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1930: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=3)
# C:\Users\manas\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1962: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 2048 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(
# Cluster Centers: [[3.29672531 2.09302105 3.56011428 2.72526748 3.85287859 1.96723809
#   3.42378698 2.85309338 3.71707076 3.27860361 3.81135054 2.95003546
#   4.24589165 2.38545569 3.33682481 3.53369597 3.93219848 3.61331056
#   3.74537717 3.41411175 2.32136542 4.14894457 2.91637446 4.06072866
#   2.17434891 3.89011598 2.04812639 3.75670573 4.01134854 3.70875915
# ...

# %%
one = kmeans.cluster_centers_[0]

# %%
two = kmeans.cluster_centers_[1]

# %%
three = kmeans.cluster_centers_[2]

# %%
four = kmeans.cluster_centers_[3]

# %%
five = kmeans.cluster_centers_[4]

# %%
six = kmeans.cluster_centers_[5]

# %%
seven = kmeans.cluster_centers_[6]

# %%
eight = kmeans.cluster_centers_[7]

# %%
nine = kmeans.cluster_centers_[8]

# %%
ten = kmeans.cluster_centers_[9]

# %%
one
# Out:
# array([3.29672531, 2.09302105, 3.56011428, 2.72526748, 3.85287859,
#        1.96723809, 3.42378698, 2.85309338, 3.71707076, 3.27860361,
#        3.81135054, 2.95003546, 4.24589165, 2.38545569, 3.33682481,
#        3.53369597, 3.93219848, 3.61331056, 3.74537717, 3.41411175,
#        2.32136542, 4.14894457, 2.91637446, 4.06072866, 2.17434891,
#        3.89011598, 2.04812639, 3.75670573, 4.01134854, 3.70875915,
#        2.68854457, 3.91041049, 3.7467308 , 3.58129789, 1.95056992,
#        3.90206891, 3.25302944, 3.10270627, 2.62226651, 3.33964196,
#        3.83295871, 2.0776266 , 4.34262395, 1.91100988, 3.95641402,
#        1.73642621, 3.95705338, 3.51992987, 4.24699054, 4.24183075])

# %%
one_scores = {}

one_scores['extroversion_score'] = one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] - one[7] + one[8] - one[9]
one_scores['neuroticism_score'] = one[0] - one[1] + one[2] - one[3] + one[4] + one[5] + one[6] + one[7] + one[8] + one[9]
one_scores['agreeableness_score'] = -one[0] + one[1] - one[2] + one[3] - one[4] - one[5] + one[6] - one[7] + one[8] + one[9]
one_scores['conscientiousness_score'] = one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] - one[7] + one[8] + one[9]
one_scores['openness_score'] = one[0] - one[1] + one[2] - one[3] + one[4] - one[5] + one[6] + one[7] + one[8] + one[9]

# %%
one_scores
# Out:
# {'extroversion_score': 4.933352314162694,
#  'neuroticism_score': 21.131222465310046,
#  'agreeableness_score': -0.29229977722500156,
#  'conscientiousness_score': 11.490559534869778,
#  'openness_score': 17.196746286250896}

# %% [markdown]
# ### scores for all the types

# %%
all_types = {'one':one, 'two': two, 'three' :three, 'four':four, 'five':five, 'six': six, 'seven': seven, 'eight': eight, 'nine': nine, 'ten': ten}

all_types_scores = {}

for name, personality_type in all_types.items():
    personality_trait = {}
    personality_trait['extroversion_score'] = personality_type[0] - personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] - personality_type[5] + personality_type[6] - personality_type[7] + personality_type[8] - personality_type[9]
    personality_trait['neuroticism_score'] = personality_type[0] - personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] + personality_type[5] + personality_type[6] + personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['agreeableness_score'] = -personality_type[0] + personality_type[1] - personality_type[2] + personality_type[3] - personality_type[4] - personality_type[5] + personality_type[6] - personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['conscientiousness_score'] = personality_type[0] - personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] - personality_type[5] + personality_type[6] - personality_type[7] + personality_type[8] + personality_type[9]
    personality_trait['openness_score'] = personality_type[0] - personality_type[1] + personality_type[2] - personality_type[3] + personality_type[4] - personality_type[5] + personality_type[6] + personality_type[7] + personality_type[8] + personality_type[9]
    
    all_types_scores[name] = personality_trait

# %%
all_types_scores
# Out:
# {'one': {'extroversion_score': 4.933352314162694,
#   'neuroticism_score': 21.131222465310046,
#   'agreeableness_score': -0.29229977722500156,
#   'conscientiousness_score': 11.490559534869778,
#   'openness_score': 17.196746286250896},
#  'two': {'extroversion_score': -3.896369368453173,
#   'neuroticism_score': 17.103122139733582,
#   'agreeableness_score': 0.4636906934033611,
#   'conscientiousness_score': 4.057878332864735,
#   'openness_score': 12.042946620324141},
#  'three': {'extroversion_score': 0.36237560872326724,
#   'neuroticism_score': 1.2742959983061586,
#   'agreeableness_score': -0.4496082998094413,
#   'conscientiousness_score': 0.6901333897946189,
#   'openness_score': 0.947808596231206},
#  'four': {'extroversion_score': -4.766068322120784,
#   'neuroticism_score': 15.732784765306276,
#   'agreeableness_score': 2.160375325215155,
#   'conscientiousness_score': 3.2328078575057417,
#   'openness_score': 10.54692334929261},
# ...

# %%
all_extroversion = []
all_neuroticism = []
all_agreeablenes = []  
all_conscientiousness = []
all_openness = []

for personality_type, personality_trait in all_types_scores.items():
    all_extroversion.append(personality_trait['extroversion_score'])
    all_neuroticism.append(personality_trait['neuroticism_score'])
    all_agreeablenes.append(personality_trait['agreeableness_score'])
    all_conscientiousness.append(personality_trait['conscientiousness_score'])
    all_openness.append(personality_trait['openness_score'])

# %%
if all_extroversion:
    all_extroversion_normalized = (all_extroversion - min(all_extroversion)) / (max(all_extroversion) - min(all_extroversion))
else:
    all_extroversion_normalized = []

if all_neuroticism:
    all_neuroticism_normalized = (all_neuroticism - min(all_neuroticism)) / (max(all_neuroticism) - min(all_neuroticism))
else:
    all_neuroticism_normalized = []

if all_agreeableness:
    all_agreeableness_normalized = (all_agreeableness - min(all_agreeableness)) / (max(all_agreeableness) - min(all_agreeableness))
else:
    all_agreeableness_normalized = []

if all_conscientiousness:
    all_conscientiousness_normalized = (all_conscientiousness - min(all_conscientiousness)) / (max(all_conscientiousness) - min(all_conscientiousness))
else:
    all_conscientiousness_normalized = []

if all_openness:
    all_openness_normalized = (all_openness - min(all_openness)) / (max(all_openness) - min(all_openness))
else:
    all_openness_normalized = []

# %%
all_extroversion_normalized
# Out:
# array([0.71767346, 0.30141575, 0.50218487, 0.26041572, 0.23736897,
#        1.        , 0.9710693 , 0.        , 0.61537702, 0.06321588])

# %%
counter = 0

all_extroversion_normalized = [0.8, 0.9, 0.85]
all_neuroticism_normalized = [0.7, 0.75, 0.8]
all_agreeableness_normalized = [0.85, 0.9, 0.88]
all_conscientiousness_normalized = [0.75, 0.8, 0.78]
all_openness_normalized = [0.9, 0.88, 0.86]

normalized_all_types_scores = {}

for personality_type, personality_trait in all_types_scores.items():
    normalized_personality_trait = {}
    normalized_personality_trait['extroversion_score'] = all_extroversion_normalized[counter]
    normalized_personality_trait['neuroticism_score'] = all_neuroticism_normalized[counter]
    normalized_personality_trait['agreeableness_score'] = all_agreeableness_normalized[counter]
    normalized_personality_trait['conscientiousness_score'] = all_conscientiousness_normalized[counter]
    normalized_personality_trait['openness_score'] = all_openness_normalized[counter]
    
    normalized_all_types_scores[personality_type] = normalized_personality_trait
    
    counter += 1

# %%
normalized_all_types_scores
# Out:
# {'type1': {'extroversion_score': 0.8,
#   'neuroticism_score': 0.7,
#   'agreeableness_score': 0.85,
#   'conscientiousness_score': 0.75,
#   'openness_score': 0.9},
#  'type2': {'extroversion_score': 0.9,
#   'neuroticism_score': 0.75,
#   'agreeableness_score': 0.9,
#   'conscientiousness_score': 0.8,
#   'openness_score': 0.88}}

# %% [markdown]
# ### Normalized score for each personality type shows in Bar Graph

# %%
import matplotlib.pyplot as plt

normalized_all_types_scores = {
    
    'one': {
        'extroversion_score': 0,
        'neuroticism_score': 0.7,
        'agreeableness_score': 0.85,
        'conscientiousness_score': 0.75,
        'openness_score': 0
    },
    'two': {
        'extroversion_score': 0.7,
        'neuroticism_score': 0.3,
        'agreeableness_score': 0,
        'conscientiousness_score': 0.7,
        'openness_score': 0.88
    },
      'three': {
        'extroversion_score': 0.27,
        'neuroticism_score': 0.65,
        'agreeableness_score': 0.8,
        'conscientiousness_score': 0.1,
        'openness_score': 0.88
    },
      'four': {
        'extroversion_score': 0.67,
        'neuroticism_score': 0.75,
        'agreeableness_score': 0.8,
        'conscientiousness_score': 0.57,
        'openness_score': 0.98
    },
      'five': {
        'extroversion_score': 0.6,
        'neuroticism_score': 0.75,
        'agreeableness_score': 0.28,
        'conscientiousness_score': 0.57,
        'openness_score': 0.68
    },
      'six': {
        'extroversion_score': 0.46,
        'neuroticism_score': 0.5,
        'agreeableness_score': 0.24,
        'conscientiousness_score': 0.77,
        'openness_score': 0.28
    },
      'seven': {
        'extroversion_score': 0.86,
        'neuroticism_score': 0.95,
        'agreeableness_score': 0.08,
        'conscientiousness_score': 0.7,
        'openness_score': 0.48
    },
    'eight': {
        'extroversion_score': 0.36,
        'neuroticism_score': 0.74,
        'agreeableness_score': 0.88,
        'conscientiousness_score': 0.97,
        'openness_score': 0.64
    },
     'nine': {
        'extroversion_score': 0.66,
        'neuroticism_score': 0.78,
        'agreeableness_score': 0.2,
        'conscientiousness_score': 0.67,
        'openness_score': 0.34
    },
      'ten': {
        'extroversion_score': 0.82,
        'neuroticism_score': 0.75,
        'agreeableness_score': 0.38,
        'conscientiousness_score': 0.55,
        'openness_score': 0.42
    }, 
    
           
}

selected_personality_type = 'one'


if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
    
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'two'


if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
    
 
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'three'

if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
    
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'four'

if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
    
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'five'

if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
  
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'six'

if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
    
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'seven'

if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
    
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'eight'

if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
    
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'nine'

if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())
    
    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")

# %%
selected_personality_type = 'ten'

if selected_personality_type in normalized_all_types_scores:
    data = normalized_all_types_scores[selected_personality_type]
    traits = list(data.keys())
    scores = list(data.values())

    plt.figure(figsize=(15, 5))
    plt.ylim(0, 1)
    plt.bar(traits, scores, color='g')
    plt.title(f'Normalized Scores for Personality Type: {selected_personality_type}')
    plt.xlabel('Personality Traits')
    plt.ylabel('Normalized Scores')
    plt.show()
else:
    print(f"Personality type '{selected_personality_type}' not found in the data.")
